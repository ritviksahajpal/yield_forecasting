# %%
import numpy as np
import pandas as pd
data = np.random.randn(3,100)
data[0, :10]
# Out:
# array([-0.01364387,  0.5222586 ,  1.15224687, -0.9266481 , -0.64540536,
#         0.39010219, -0.76895196, -0.07288328, -0.69150587, -1.23201017])

# %%
##PLOT

# %%
import matplotlib.pyplot as plt
plt.scatter(data[0],data[1],c=data[2], s=100*np.abs(data[2]))
